# %%
import json
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import RDF, XSD, RDFS, OWL
from neo4j import GraphDatabase

# Define namespaces
EX = Namespace("http://example.org/")

# Neo4j connection
uri = "bolt://localhost:7687"  # Change if necessary
username = "neo4j"  # Replace with your Neo4j username
password = "Neo4jpassword"  # Replace with your Neo4j password
driver = GraphDatabase.driver(uri, auth=(username, password))

# Load JSON Data
def load_json_data(financial_file, eod_file):
    with open(financial_file, 'r', encoding='utf-8') as file:
        financial_data = json.load(file)
    with open(eod_file, 'r', encoding='utf-8') as file:
        eod_data = json.load(file)
    return financial_data, eod_data

# Add schema definitions to RDF Graph
def add_schema_definitions(g):
    # Class definitions
    g.add((EX.Company, RDF.type, OWL.Class))
    g.add((EX.Security, RDF.type, OWL.Class))
    g.add((EX.StockValue, RDF.type, OWL.Class))
    g.add((EX.FinancialStatement, RDF.type, OWL.Class))
    g.add((EX.IndustrialClassification, RDF.type, OWL.Class))

    # Property definitions
    g.add((EX.hasPrice, RDF.type, OWL.ObjectProperty))
    g.add((EX.hasPrice, RDFS.domain, EX.Company))
    g.add((EX.hasPrice, RDFS.range, EX.Security))

    g.add((EX.name, RDF.type, OWL.DatatypeProperty))
    g.add((EX.name, RDFS.domain, OWL.Thing))
    g.add((EX.name, RDFS.range, XSD.string))

    g.add((EX.isPriceOf, RDF.type, OWL.ObjectProperty))
    g.add((EX.isPriceOf, OWL.inverseOf, EX.hasPrice))

    # StockValue attributes
    for attribute in ['has_average', 'has_close', 'has_high', 'has_low', 'has_open', 'has_prior', 'has_totalVolume']:
        g.add((getattr(EX, attribute), RDF.type, OWL.DatatypeProperty))
        g.add((getattr(EX, attribute), RDFS.domain, EX.StockValue))
        g.add((getattr(EX, attribute), RDFS.range, XSD.float))

    g.add((EX.hasFinancialStatement, RDF.type, OWL.ObjectProperty))
    g.add((EX.hasFinancialStatement, RDFS.domain, EX.Company))
    g.add((EX.hasFinancialStatement, RDFS.range, EX.FinancialStatement))

    g.add((EX.hasYear, RDF.type, OWL.DatatypeProperty))
    g.add((EX.hasYear, RDFS.domain, EX.FinancialStatement))
    g.add((EX.hasYear, RDFS.range, XSD.integer))

    g.add((EX.hasQuarter, RDF.type, OWL.DatatypeProperty))
    g.add((EX.hasQuarter, RDFS.domain, EX.FinancialStatement))
    g.add((EX.hasQuarter, RDFS.range, XSD.integer))

    # Financial statement properties
    financial_key_list = ["totalAssets", "totalLiabilities", "paidupShareCapital", "shareholderEquity",
                          "totalEquity", "totalRevenueQuarter", "totalRevenueAccum", "totalExpensesQuarter", "totalExpensesAccum",
                          "ebitQuarter", "ebitAccum", "netProfitQuarter", "netProfitAccum", "epsQuarter", "epsAccum",
                          "operatingCashFlow", "investingCashFlow", "financingCashFlow", "roe",
                          "roa", "netProfitMarginQuarter", "netProfitMarginAccum", "de", "fixedAssetTurnover", "totalAssetTurnover"]
    for key in financial_key_list:
        prop_uri = EX[f"has_{key}"]
        g.add((prop_uri, RDF.type, OWL.DatatypeProperty))
        g.add((prop_uri, RDFS.domain, EX.FinancialStatement))
        g.add((prop_uri, RDFS.range, XSD.float))

    g.add((EX.hasIndustrialClassification, RDF.type, OWL.ObjectProperty))
    g.add((EX.hasIndustrialClassification, RDFS.domain, EX.Company))
    g.add((EX.hasIndustrialClassification, RDFS.range, EX.IndustrialClassification))

    classification_key_list = ['marketCode', 'marketSegment', 'sectorCode']
    for key in classification_key_list:
        prop_uri = EX[f"has_{key}"]
        g.add((prop_uri, RDF.type, OWL.DatatypeProperty))
        g.add((prop_uri, RDFS.domain, EX.IndustrialClassification))
        g.add((prop_uri, RDFS.range, XSD.string))

# Create RDF Graph
def create_rdf_graph(financial_data, eod_data):
    g = Graph()
    g.bind("ex", EX)

    add_schema_definitions(g)
    
    # Helper functions for adding nodes
    def add_stock_value_node(item, g, price_uri_in_dict, price_symbol_in_json):
        stock_value_uri = EX[f"stock_value_{price_symbol_in_json}_{item['date']}"]
        g.add((stock_value_uri, RDF.type, EX.StockValue))
        g.add((price_uri_in_dict, EX.hasStockValue, stock_value_uri))
        
        key_list = ['prior', 'open', 'high', 'low', 'close', 'average', 'totalVolume']
        if item['date'] is not None:
            for key in key_list:
                if key in item and item[key] is not None:
                    g.add((stock_value_uri, EX[key], Literal(item[key], datatype=XSD.float)))
                else:
                    print(f"Missing or None value for {key} in item:", item)
        return

    def add_financial_statement_node(item, g, company_uri_in_dict, price_symbol_in_json):
        year = item['year']
        quarter = item['quarter']
        financial_statement_uri = EX[f"financial_statement_{price_symbol_in_json}_year{year}_quarter{quarter}"]
        g.add((financial_statement_uri, RDF.type, EX.FinancialStatement))
        g.add((company_uri_in_dict, EX.hasFinancialStatement, financial_statement_uri))
        g.add((financial_statement_uri, EX.hasYear, Literal(year, datatype=XSD.integer)))
        g.add((financial_statement_uri, EX.hasQuarter, Literal(quarter, datatype=XSD.integer)))
        
        key_list_float = ["totalAssets", "totalLiabilities", "paidupShareCapital", "shareholderEquity",
                        "totalEquity", "totalRevenueQuarter", "totalRevenueAccum", "totalExpensesQuarter", "totalExpensesAccum",
                        "ebitQuarter", "ebitAccum", "netProfitQuarter", "netProfitAccum", "epsQuarter", "epsAccum",
                        "operatingCashFlow", "investingCashFlow", "financingCashFlow", "roe",
                        "roa", "netProfitMarginQuarter", "netProfitMarginAccum", "de", "fixedAssetTurnover", "totalAssetTurnover"]
        
        for key in key_list_float:
            if key in item and item[key] is not None:
                g.add((financial_statement_uri, EX[key], Literal(item[key], datatype=XSD.float)))
#            else:
#                    print(f"Missing or None value for {key} in item:", item)
        return

    def add_industrial_classification_node(item, g, company_uri_in_dict, price_symbol_in_json):
        industrial_classification_uri = EX[f"industrial_classification_{price_symbol_in_json}"]
        g.add((industrial_classification_uri, RDF.type, EX.IndustrialClassification))
        g.add((company_uri_in_dict, EX.hasIndustrialClassification, industrial_classification_uri))
        
        key_list = ['marketCode', 'marketSegment', 'sectorCode']
        for key in key_list:
            if key in item and item[key] is not None:
                g.add((industrial_classification_uri, EX[key], Literal(item[key])))
        return

    # Create nodes and relationships
    for entry in financial_data:
        company_uri = EX[entry['symbol']]
        add_financial_statement_node(entry, g, company_uri, entry['symbol'])
        add_industrial_classification_node(entry, g, company_uri, entry['symbol'])
    
    for entry in eod_data:
        company_uri = EX[entry['symbol']]
        add_stock_value_node(entry, g, company_uri, entry['symbol'])
    
    return g

# Insert RDF data into Neo4j
def insert_data_into_neo4j(graph, driver):
    with driver.session() as session:
        tx = session.begin_transaction()

        for s, p, o in graph:
            if (p == RDF.type):
                tx.run("MERGE (a:Label {uri: $subject})", subject=str(s))
            elif isinstance(o, Literal):
                predicate = str(p).split('/')[-1]
                query = (
                    "MATCH (a {uri: $subject}) "
                    "SET a." + predicate + " = $object "
                )
                tx.run(query, subject=str(s), object=o.toPython())
            else:
                tx.run(
                    "MERGE (a {uri: $subject}) "
                    "MERGE (b {uri: $object}) "
                    "MERGE (a)-[r:RELATION {type: $predicate}]->(b) ",
                    subject=str(s), predicate=str(p), object=str(o)
                )
                
        tx.commit()

# Main function
def main(financial_file, eod_file):
    financial_data, eod_data = load_json_data(financial_file, eod_file)
    rdf_graph = create_rdf_graph(financial_data, eod_data)
    insert_data_into_neo4j(rdf_graph, driver)

# File paths
financial_file = "C:\\study\\thesis\\Naphattha\\FilteredFinancialData.json"
eod_file = "C:\\study\\thesis\\Naphattha\\FilteredEODData.json"
main(financial_file, eod_file)
# Out:
# Failed to write data to connection IPv4Address(('localhost', 7687)) (ResolvedIPv4Address(('127.0.0.1', 7687)))
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'BBL', 'year': '2019', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2019-03-31', 'accountPeriod': 'C', 'totalAssets': 3148836302.0, 'totalLiabilities': 2723140802.0, 'paidupShareCapital': 19088429.0, 'shareholderEquity': 425255994.0, 'totalEquity': 425695500.0, 'totalRevenueQuarter': 38862314.0, 'totalRevenueAccum': 38862314.0, 'totalExpensesQuarter': 30092113.0, 'totalExpensesAccum': 30092113.0, 'ebitQuarter': 21413289.0, 'ebitAccum': 21413289.0, 'netProfitQuarter': 9028296.0, 'netProfitAccum': 9028296.0, 'epsQuarter': 4.73, 'epsAccum': 4.73, 'operatingCashFlow': 9102208.0, 'investingCashFlow': -12584040.0, 'financingCashFlow': 43414.0, 'roe': 8.51157912967361, 'roa': 2.657317017802743, 'netProfitMarginQuarter': 23.475593861960974, 'netProfitMarginAccum': 23.475593861960974, 'de': 6.396921748057003, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.049008892175058605}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KBANK', 'year': '2019', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2019-03-31', 'accountPeriod': 'C', 'totalAssets': 3150640953.0, 'totalLiabilities': 2714117289.0, 'paidupShareCapital': 23932602.0, 'shareholderEquity': 391898219.0, 'totalEquity': 436523664.0, 'totalRevenueQuarter': 45117050.0, 'totalRevenueAccum': 45117050.0, 'totalExpensesQuarter': 33723683.0, 'totalExpensesAccum': 33723683.0, 'ebitQuarter': 20617488.0, 'ebitAccum': 20617488.0, 'netProfitQuarter': 10044424.0, 'netProfitAccum': 10044424.0, 'epsQuarter': 4.2, 'epsAccum': 4.2, 'operatingCashFlow': 25802171.0, 'investingCashFlow': -35314458.0, 'financingCashFlow': 66207.0, 'roe': 10.029536181148515, 'roa': 2.5842636741975555, 'netProfitMarginQuarter': 24.961609857027444, 'netProfitMarginAccum': 24.961609857027444, 'de': 6.217571950463607, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.059226056216228784}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTB', 'year': '2019', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2019-03-31', 'accountPeriod': 'C', 'totalAssets': 2884114009.0, 'totalLiabilities': 2560142768.0, 'paidupShareCapital': 72005040.0, 'shareholderEquity': 314902144.0, 'totalEquity': 323971241.0, 'totalRevenueQuarter': 42102395.0, 'totalRevenueAccum': 42102395.0, 'totalExpensesQuarter': 33704753.0, 'totalExpensesAccum': 33704753.0, 'ebitQuarter': 18781950.0, 'ebitAccum': 18781950.0, 'netProfitQuarter': 7301082.0, 'netProfitAccum': 7301082.0, 'epsQuarter': 0.52, 'epsAccum': 0.52, 'operatingCashFlow': 22174899.0, 'investingCashFlow': -31049850.0, 'financingCashFlow': 2100000.0, 'roe': 9.544788477196105, 'roa': 2.590370526889888, 'netProfitMarginQuarter': 19.249558130837926, 'netProfitMarginAccum': 19.249558130837926, 'de': 7.902376643363847, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.05470331999024502}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTC', 'year': '2019', 'quarter': '1', 'financialStatementType': 'U', 'dateAsof': '2019-03-31', 'accountPeriod': 'C', 'totalAssets': 76173970.0, 'totalLiabilities': 58232939.0, 'paidupShareCapital': 2578334.0, 'shareholderEquity': 17941031.0, 'totalEquity': 17941031.0, 'totalRevenueQuarter': 4587432.0, 'totalRevenueAccum': 4587432.0, 'totalExpensesQuarter': 2641963.0, 'totalExpensesAccum': 2641963.0, 'ebitQuarter': 2363905.0, 'ebitAccum': 2363905.0, 'netProfitQuarter': 1589420.0, 'netProfitAccum': 1589420.0, 'epsQuarter': 0.62, 'epsAccum': 0.62, 'operatingCashFlow': 3316350.0, 'investingCashFlow': -131236.0, 'financingCashFlow': -3567690.0, 'roe': 34.797281101326874, 'roa': 11.553313774636942, 'netProfitMarginQuarter': 34.64727106581634, 'netProfitMarginAccum': 34.64727106581634, 'de': 3.245796688049867, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.2472919983467199}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'MTC', 'year': '2019', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2019-03-31', 'accountPeriod': 'C', 'totalAssets': 51946461.0, 'totalLiabilities': 38640032.0, 'paidupShareCapital': 2120000.0, 'shareholderEquity': 13306429.0, 'totalEquity': 13306429.0, 'totalRevenueQuarter': 2857968.0, 'totalRevenueAccum': 2857968.0, 'totalExpensesQuarter': 1601768.0, 'totalExpensesAccum': 1601768.0, 'ebitQuarter': 1587324.0, 'ebitAccum': 1587324.0, 'netProfitQuarter': 1005364.0, 'netProfitAccum': 1005364.0, 'epsQuarter': 0.47, 'epsAccum': 0.47, 'operatingCashFlow': -1108191.0, 'investingCashFlow': -118557.0, 'financingCashFlow': 1306996.0, 'roe': 33.65689011688337, 'roa': 13.304579954277283, 'netProfitMarginQuarter': 35.1775807146896, 'netProfitMarginAccum': 35.1775807146896, 'de': 2.9038618851083187, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.24058750848055477}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TISCO', 'year': '2019', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2019-03-31', 'accountPeriod': 'C', 'totalAssets': 297899703.0, 'totalLiabilities': 258269897.0, 'paidupShareCapital': 8006555.0, 'shareholderEquity': 39495100.0, 'totalEquity': 39629806.0, 'totalRevenueQuarter': 5996152.0, 'totalRevenueAccum': 5996152.0, 'totalExpensesQuarter': 3773090.0, 'totalExpensesAccum': 3773090.0, 'ebitQuarter': 3449548.0, 'ebitAccum': 3449548.0, 'netProfitQuarter': 1729598.0, 'netProfitAccum': 1729598.0, 'epsQuarter': 2.16, 'epsAccum': 2.16, 'operatingCashFlow': 8566533.0, 'investingCashFlow': 1601459.0, 'financingCashFlow': -10000000.0, 'roe': 18.404935947193426, 'roa': 4.575468426811491, 'netProfitMarginQuarter': 28.876419410315147, 'netProfitMarginAccum': 28.876419410315147, 'de': 6.517061854907895, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.07971549130252337}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TTB', 'year': '2019', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2019-03-31', 'accountPeriod': 'C', 'totalAssets': 892224013.0, 'totalLiabilities': 791830425.0, 'paidupShareCapital': 41659299.0, 'shareholderEquity': 100393588.0, 'totalEquity': 100393588.0, 'totalRevenueQuarter': 11667376.0, 'totalRevenueAccum': 11667376.0, 'totalExpensesQuarter': 10148564.0, 'totalExpensesAccum': 10148564.0, 'ebitQuarter': 4753794.0, 'ebitAccum': 4753794.0, 'netProfitQuarter': 1578838.0, 'netProfitAccum': 1578838.0, 'epsQuarter': 0.04, 'epsAccum': 0.04, 'operatingCashFlow': 4613261.0, 'investingCashFlow': -7780091.0, 'financingCashFlow': -378944.0, 'roe': 11.323915810289153, 'roa': 2.8497008939853012, 'netProfitMarginQuarter': 13.532074392734065, 'netProfitMarginAccum': 13.532074392734065, 'de': 7.887260937421621, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.055673443518931706}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'BBL', 'year': '2019', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2019-06-30', 'accountPeriod': 'C', 'totalAssets': 3146108663.0, 'totalLiabilities': 2722608753.0, 'paidupShareCapital': 19088429.0, 'shareholderEquity': 423161290.0, 'totalEquity': 423499910.0, 'totalRevenueQuarter': 39692350.0, 'totalRevenueAccum': 78554664.0, 'totalExpensesQuarter': 32561662.0, 'totalExpensesAccum': 62653775.0, 'ebitQuarter': 21890936.0, 'ebitAccum': 43304225.0, 'netProfitQuarter': 9347005.0, 'netProfitAccum': 18375301.0, 'epsQuarter': 4.9, 'epsAccum': 9.63, 'operatingCashFlow': 21471263.0, 'investingCashFlow': -20161914.0, 'financingCashFlow': -8466435.0, 'roe': 8.628405452661022, 'roa': 2.678901144638393, 'netProfitMarginQuarter': 23.800107577404713, 'netProfitMarginAccum': 23.639565182278673, 'de': 6.428829590542298, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.049259157789952955}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KBANK', 'year': '2019', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2019-06-30', 'accountPeriod': 'C', 'totalAssets': 3256294111.0, 'totalLiabilities': 2813768779.0, 'paidupShareCapital': 23932602.0, 'shareholderEquity': 395840611.0, 'totalEquity': 442525332.0, 'totalRevenueQuarter': 46858580.0, 'totalRevenueAccum': 91975630.0, 'totalExpensesQuarter': 35425922.0, 'totalExpensesAccum': 69149605.0, 'ebitQuarter': 20967238.0, 'ebitAccum': 41584726.0, 'netProfitQuarter': 9928804.0, 'netProfitAccum': 19973228.0, 'epsQuarter': 4.15, 'epsAccum': 8.35, 'operatingCashFlow': 87969764.0, 'investingCashFlow': -97608432.0, 'financingCashFlow': -9318057.0, 'roe': 9.708229938805882, 'roa': 2.4850521697250554, 'netProfitMarginQuarter': 24.38224760545454, 'netProfitMarginAccum': 24.66644370905641, 'de': 6.3584354962983225, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.058147915669068746}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTB', 'year': '2019', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2019-06-30', 'accountPeriod': 'C', 'totalAssets': 2727006835.0, 'totalLiabilities': 2399672809.0, 'paidupShareCapital': 72005040.0, 'shareholderEquity': 318630909.0, 'totalEquity': 327334026.0, 'totalRevenueQuarter': 38634791.0, 'totalRevenueAccum': 80737186.0, 'totalExpensesQuarter': 29161157.0, 'totalExpensesAccum': 62865910.0, 'ebitQuarter': 19384727.0, 'ebitAccum': 38166677.0, 'netProfitQuarter': 8169676.0, 'netProfitAccum': 15470758.0, 'epsQuarter': 0.59, 'epsAccum': 1.11, 'operatingCashFlow': 59263202.0, 'investingCashFlow': -62844023.0, 'financingCashFlow': -10436680.0, 'roe': 9.703354840173416, 'roa': 2.697473320646176, 'netProfitMarginQuarter': 22.94453462942248, 'netProfitMarginAccum': 21.01769809019601, 'de': 7.330960481939021, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.057235996767038666}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTC', 'year': '2019', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2019-06-30', 'accountPeriod': 'C', 'totalAssets': 78356381.0, 'totalLiabilities': 61188831.0, 'paidupShareCapital': 2578334.0, 'shareholderEquity': 17150069.0, 'totalEquity': 17167550.0, 'totalRevenueQuarter': 4668262.0, 'totalRevenueAccum': 9255694.0, 'totalExpensesQuarter': 3053061.0, 'totalExpensesAccum': 5695024.0, 'ebitQuarter': 2047700.0, 'ebitAccum': 4411605.0, 'netProfitQuarter': 1323268.0, 'netProfitAccum': 2912688.0, 'epsQuarter': 0.51, 'epsAccum': 1.13, 'operatingCashFlow': 2852956.0, 'investingCashFlow': -201877.0, 'financingCashFlow': -2742243.0, 'roe': 35.869664494028214, 'roa': 11.264424568509071, 'netProfitMarginQuarter': 28.346395296579328, 'netProfitMarginAccum': 31.46932039888095, 'de': 3.5642145210003755, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.24466595014778145}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'MTC', 'year': '2019', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2019-06-30', 'accountPeriod': 'C', 'totalAssets': 55813096.0, 'totalLiabilities': 42036944.0, 'paidupShareCapital': 2120000.0, 'shareholderEquity': 13776152.0, 'totalEquity': 13776152.0, 'totalRevenueQuarter': 3070855.0, 'totalRevenueAccum': 5928823.0, 'totalExpensesQuarter': 1784032.0, 'totalExpensesAccum': 3385800.0, 'ebitQuarter': 1649568.0, 'ebitAccum': 3236892.0, 'netProfitQuarter': 1020777.0, 'netProfitAccum': 2026141.0, 'epsQuarter': 0.48, 'epsAccum': 0.96, 'operatingCashFlow': -3713128.0, 'investingCashFlow': -283249.0, 'financingCashFlow': 4064191.0, 'roe': 33.15218228091544, 'roa': 12.797015806383145, 'netProfitMarginQuarter': 33.24080752754526, 'netProfitMarginAccum': 34.174422140785786, 'de': 3.0514285847020273, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.2328287017706422}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TISCO', 'year': '2019', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2019-06-30', 'accountPeriod': 'C', 'totalAssets': 292379052.0, 'totalLiabilities': 256730249.0, 'paidupShareCapital': 8006555.0, 'shareholderEquity': 35550829.0, 'totalEquity': 35648803.0, 'totalRevenueQuarter': 6006211.0, 'totalRevenueAccum': 12002362.0, 'totalExpensesQuarter': 3759645.0, 'totalExpensesAccum': 7532735.0, 'ebitQuarter': 3511321.0, 'ebitAccum': 6960869.0, 'netProfitQuarter': 1798153.0, 'netProfitAccum': 3527751.0, 'epsQuarter': 2.25, 'epsAccum': 4.41, 'operatingCashFlow': 31525320.0, 'investingCashFlow': -2976672.0, 'financingCashFlow': -28604429.0, 'roe': 20.345900855633, 'roa': 4.554323198701701, 'netProfitMarginQuarter': 29.981464187655078, 'netProfitMarginAccum': 29.42939897996744, 'de': 7.201651314912313, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.08028201224709096}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TTB', 'year': '2019', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2019-06-30', 'accountPeriod': 'C', 'totalAssets': 899799635.0, 'totalLiabilities': 799362048.0, 'paidupShareCapital': 41659299.0, 'shareholderEquity': 100437587.0, 'totalEquity': 100437587.0, 'totalRevenueQuarter': 12028626.0, 'totalRevenueAccum': 23696002.0, 'totalExpensesQuarter': 10309726.0, 'totalExpensesAccum': 20458290.0, 'ebitQuarter': 5085635.0, 'ebitAccum': 9839429.0, 'netProfitQuarter': 1917319.0, 'netProfitAccum': 3496157.0, 'epsQuarter': 0.04, 'epsAccum': 0.08, 'operatingCashFlow': -19907820.0, 'investingCashFlow': -1643582.0, 'financingCashFlow': 17188487.0, 'roe': 11.244793683589496, 'roa': 2.799184924902528, 'netProfitMarginQuarter': 15.939634335625698, 'netProfitMarginAccum': 14.754206215884013, 'de': 7.958793832830731, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.05453597566907424}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'BBL', 'year': '2019', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2019-09-30', 'accountPeriod': 'C', 'totalAssets': 3228091787.0, 'totalLiabilities': 2797653747.0, 'paidupShareCapital': 19088429.0, 'shareholderEquity': 430178280.0, 'totalEquity': 430438040.0, 'totalRevenueQuarter': 39798759.0, 'totalRevenueAccum': 118340874.0, 'totalExpensesQuarter': 31201113.0, 'totalExpensesAccum': 93842338.0, 'ebitQuarter': 22706465.0, 'ebitAccum': 66010690.0, 'netProfitQuarter': 9438412.0, 'netProfitAccum': 27813713.0, 'epsQuarter': 4.94, 'epsAccum': 14.57, 'operatingCashFlow': 14675586.0, 'investingCashFlow': -49507549.0, 'financingCashFlow': 24379890.0, 'roe': 8.60491932444888, 'roa': 2.7255595819252267, 'netProfitMarginQuarter': 23.96947854580089, 'netProfitMarginAccum': 23.753023828436486, 'de': 6.4995504277456515, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.04990142274638341}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KBANK', 'year': '2019', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2019-09-30', 'accountPeriod': 'C', 'totalAssets': 3240134170.0, 'totalLiabilities': 2791550954.0, 'paidupShareCapital': 23932602.0, 'shareholderEquity': 401044734.0, 'totalEquity': 448583216.0, 'totalRevenueQuarter': 47399974.0, 'totalRevenueAccum': 139375605.0, 'totalExpensesQuarter': 38306004.0, 'totalExpensesAccum': 107455609.0, 'ebitQuarter': 20933500.0, 'ebitAccum': 62518226.0, 'netProfitQuarter': 9951374.0, 'netProfitAccum': 29924602.0, 'epsQuarter': 4.16, 'epsAccum': 12.5, 'operatingCashFlow': 91128801.0, 'investingCashFlow': -97831937.0, 'financingCashFlow': -10404023.0, 'roe': 9.579704441107276, 'roa': 2.5121625565070445, 'netProfitMarginQuarter': 23.9058253491869, 'netProfitMarginAccum': 24.407766337588274, 'de': 6.2230392364925216, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.058883133155095295}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTB', 'year': '2019', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2019-09-30', 'accountPeriod': 'C', 'totalAssets': 2913358939.0, 'totalLiabilities': 2568226167.0, 'paidupShareCapital': 72005040.0, 'shareholderEquity': 335737819.0, 'totalEquity': 345132772.0, 'totalRevenueQuarter': 38598593.0, 'totalRevenueAccum': 119301904.0, 'totalExpensesQuarter': 32491566.0, 'totalExpensesAccum': 95323601.0, 'ebitQuarter': 16875630.0, 'ebitAccum': 55042307.0, 'netProfitQuarter': 6354570.0, 'netProfitAccum': 21825328.0, 'epsQuarter': 0.45, 'epsAccum': 1.56, 'operatingCashFlow': 40748115.0, 'investingCashFlow': -64855012.0, 'financingCashFlow': 12678320.0, 'roe': 8.835876815232506, 'roa': 2.560169463906166, 'netProfitMarginQuarter': 18.235112870564997, 'netProfitMarginAccum': 20.123396354177213, 'de': 7.441270071565386, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.05615313672780224}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTC', 'year': '2019', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2019-09-30', 'accountPeriod': 'C', 'totalAssets': 79028034.0, 'totalLiabilities': 60558297.0, 'paidupShareCapital': 2578334.0, 'shareholderEquity': 18442264.0, 'totalEquity': 18469737.0, 'totalRevenueQuarter': 4733232.0, 'totalRevenueAccum': 13988926.0, 'totalExpensesQuarter': 3150537.0, 'totalExpensesAccum': 8845561.0, 'ebitQuarter': 2010258.0, 'ebitAccum': 6421863.0, 'netProfitQuarter': 1292195.0, 'netProfitAccum': 4204883.0, 'epsQuarter': 0.5, 'epsAccum': 1.63, 'operatingCashFlow': 1108660.0, 'investingCashFlow': -292541.0, 'financingCashFlow': -2367003.0, 'roe': 32.37676455093657, 'roa': 10.953559455978475, 'netProfitMarginQuarter': 27.300732353706728, 'netProfitMarginAccum': 30.058855125833105, 'de': 3.278785020057405, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.2443696134033283}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'MTC', 'year': '2019', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2019-09-30', 'accountPeriod': 'C', 'totalAssets': 59207470.0, 'totalLiabilities': 44351360.0, 'paidupShareCapital': 2120000.0, 'shareholderEquity': 14856110.0, 'totalEquity': 14856110.0, 'totalRevenueQuarter': 3304135.0, 'totalRevenueAccum': 9232958.0, 'totalExpensesQuarter': 1951853.0, 'totalExpensesAccum': 5337653.0, 'ebitQuarter': 1759783.0, 'ebitAccum': 4996675.0, 'netProfitQuarter': 1080404.0, 'netProfitAccum': 3106545.0, 'epsQuarter': 0.51, 'epsAccum': 1.47, 'operatingCashFlow': -5475527.0, 'investingCashFlow': -478076.0, 'financingCashFlow': 6029272.0, 'roe': 31.433196342913483, 'roa': 12.527509027628447, 'netProfitMarginQuarter': 32.69854288641354, 'netProfitMarginAccum': 33.646259411122635, 'de': 2.98539523468795, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.22991856642545816}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TISCO', 'year': '2019', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2019-09-30', 'accountPeriod': 'C', 'totalAssets': 283866231.0, 'totalLiabilities': 246471341.0, 'paidupShareCapital': 8006555.0, 'shareholderEquity': 37390504.0, 'totalEquity': 37394890.0, 'totalRevenueQuarter': 6064525.0, 'totalRevenueAccum': 18066887.0, 'totalExpensesQuarter': 3763458.0, 'totalExpensesAccum': 11296193.0, 'ebitQuarter': 3601586.0, 'ebitAccum': 10562456.0, 'netProfitQuarter': 1877741.0, 'netProfitAccum': 5405492.0, 'epsQuarter': 2.35, 'epsAccum': 6.75, 'operatingCashFlow': 35672596.0, 'investingCashFlow': 836486.0, 'financingCashFlow': -36604429.0, 'roe': 19.49268431650563, 'roa': 4.751639018728821, 'netProfitMarginQuarter': 30.936025492515903, 'netProfitMarginAccum': 29.93513492390803, 'de': 6.59104334843611, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.08187438429578116}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TTB', 'year': '2019', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2019-09-30', 'accountPeriod': 'C', 'totalAssets': 900901026.0, 'totalLiabilities': 798308773.0, 'paidupShareCapital': 41659299.0, 'shareholderEquity': 102592253.0, 'totalEquity': 102592253.0, 'totalRevenueQuarter': 12086728.0, 'totalRevenueAccum': 35782731.0, 'totalExpensesQuarter': 11764796.0, 'totalExpensesAccum': 32223086.0, 'ebitQuarter': 5682649.0, 'ebitAccum': 15522079.0, 'netProfitQuarter': 2111181.0, 'netProfitAccum': 5607338.0, 'epsQuarter': 0.05, 'epsAccum': 0.13, 'operatingCashFlow': -43277218.0, 'investingCashFlow': 28272287.0, 'financingCashFlow': 10571376.0, 'roe': 7.322808896912874, 'roa': 2.29961970655061, 'netProfitMarginQuarter': 17.4669356338622, 'netProfitMarginAccum': 15.670514360684209, 'de': 7.78137480809589, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.05386527908596753}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'BBL', 'year': '2019', 'quarter': '4', 'financialStatementType': 'C', 'dateAsof': '2019-12-31', 'accountPeriod': 'C', 'totalAssets': 3216743095.0, 'totalLiabilities': 2788626786.0, 'paidupShareCapital': 19088429.0, 'shareholderEquity': 427751210.0, 'totalEquity': 428116309.0, 'totalRevenueQuarter': 39969763.0, 'totalRevenueAccum': 158310637.0, 'totalExpensesQuarter': 45741179.0, 'totalExpensesAccum': 139583517.0, 'ebitQuarter': 21914993.0, 'ebitAccum': 87925683.0, 'netProfitQuarter': 8002381.0, 'netProfitAccum': 35816094.0, 'epsQuarter': 4.19, 'epsAccum': 18.76, 'operatingCashFlow': 56190876.0, 'investingCashFlow': -84767673.0, 'financingCashFlow': 24397512.0, 'roe': 8.521904786622816, 'roa': 2.7765303781478576, 'netProfitMarginQuarter': 20.273272573570175, 'netProfitMarginAccum': 22.874467367597035, 'de': 6.513713043340285, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.049991569905057}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KBANK', 'year': '2019', 'quarter': '4', 'financialStatementType': 'C', 'dateAsof': '2019-12-31', 'accountPeriod': 'C', 'totalAssets': 3293888989.0, 'totalLiabilities': 2840174270.0, 'paidupShareCapital': 23932602.0, 'shareholderEquity': 406357615.0, 'totalEquity': 453714719.0, 'totalRevenueQuarter': 45626776.0, 'totalRevenueAccum': 185002381.0, 'totalExpensesQuarter': 40614997.0, 'totalExpensesAccum': 148070606.0, 'ebitQuarter': 18721907.0, 'ebitAccum': 81240133.0, 'netProfitQuarter': 8802140.0, 'netProfitAccum': 38726742.0, 'epsQuarter': 3.68, 'epsAccum': 16.18, 'operatingCashFlow': 102214226.0, 'investingCashFlow': -111462867.0, 'financingCashFlow': 3900048.0, 'roe': 9.896246414359586, 'roa': 2.5194723985705374, 'netProfitMarginQuarter': 20.651233389797255, 'netProfitMarginAccum': 23.48129995148549, 'de': 6.259823962202117, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.057374154298754095}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTB', 'year': '2019', 'quarter': '4', 'financialStatementType': 'C', 'dateAsof': '2019-12-31', 'accountPeriod': 'C', 'totalAssets': 3012216120.0, 'totalLiabilities': 2663889734.0, 'paidupShareCapital': 72005040.0, 'shareholderEquity': 338287296.0, 'totalEquity': 348326386.0, 'totalRevenueQuarter': 38376818.0, 'totalRevenueAccum': 157678722.0, 'totalExpensesQuarter': 31977580.0, 'totalExpensesAccum': 127301181.0, 'ebitQuarter': 18983476.0, 'ebitAccum': 74025783.0, 'netProfitQuarter': 7458714.0, 'netProfitAccum': 29284042.0, 'epsQuarter': 0.53, 'epsAccum': 2.09, 'operatingCashFlow': 153939258.0, 'investingCashFlow': -146979704.0, 'financingCashFlow': -7388091.0, 'roe': 9.092125313766788, 'roa': 2.5741744427647766, 'netProfitMarginQuarter': 21.18520613147239, 'netProfitMarginAccum': 20.381826154070428, 'de': 7.647682866034731, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.054831238507833426}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTC', 'year': '2019', 'quarter': '4', 'financialStatementType': 'C', 'dateAsof': '2019-12-31', 'accountPeriod': 'C', 'totalAssets': 85409262.23, 'totalLiabilities': 65674217.99, 'paidupShareCapital': 2578334.07, 'shareholderEquity': 19707706.41, 'totalEquity': 19735044.24, 'totalRevenueQuarter': 4744990.24, 'totalRevenueAccum': 18979960.97, 'totalExpensesQuarter': 2664707.5, 'totalExpensesAccum': 10658829.98, 'ebitQuarter': 2117560.45, 'ebitAccum': 8470241.8, 'netProfitQuarter': 1381017.96, 'netProfitAccum': 5524071.85, 'epsQuarter': 0.54, 'epsAccum': 2.14, 'operatingCashFlow': -2211367.57, 'investingCashFlow': -487321.76, 'financingCashFlow': 1324912.31, 'roe': 28.03000884566151, 'roa': 9.917240330668527, 'netProfitMarginQuarter': 29.1041936895533, 'netProfitMarginAccum': 29.10419356884484, 'de': 3.3277968466312395, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.22222368481404922}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'MTC', 'year': '2019', 'quarter': '4', 'financialStatementType': 'C', 'dateAsof': '2019-12-31', 'accountPeriod': 'C', 'totalAssets': 61871602.22, 'totalLiabilities': 45899888.41, 'paidupShareCapital': 2120000.0, 'shareholderEquity': 15971713.81, 'totalEquity': 15971713.81, 'totalRevenueQuarter': 3171982.38, 'totalRevenueAccum': 12687929.5, 'totalExpensesQuarter': 1467100.24, 'totalExpensesAccum': 5868400.96, 'ebitQuarter': 1704882.14, 'ebitAccum': 6819528.54, 'netProfitQuarter': 1059367.16, 'netProfitAccum': 4237468.63, 'epsQuarter': 0.5, 'epsAccum': 2.0, 'operatingCashFlow': -5991775.47, 'investingCashFlow': -790637.67, 'financingCashFlow': 6685421.03, 'roe': 26.531082890722043, 'roa': 11.022065528142388, 'netProfitMarginQuarter': 33.39763696921923, 'netProfitMarginAccum': 33.3976369430489, 'de': 2.873823620685074, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.20506870752893847}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TISCO', 'year': '2019', 'quarter': '4', 'financialStatementType': 'C', 'dateAsof': '2019-12-31', 'accountPeriod': 'C', 'totalAssets': 298304095.0, 'totalLiabilities': 259107981.0, 'paidupShareCapital': 8006555.0, 'shareholderEquity': 39192983.0, 'totalEquity': 39196114.0, 'totalRevenueQuarter': 6788612.0, 'totalRevenueAccum': 24855499.0, 'totalExpensesQuarter': 4498253.0, 'totalExpensesAccum': 15794446.0, 'ebitQuarter': 3582093.0, 'ebitAccum': 14144549.0, 'netProfitQuarter': 1864741.0, 'netProfitAccum': 7270233.0, 'epsQuarter': 2.33, 'epsAccum': 9.08, 'operatingCashFlow': 37180946.0, 'investingCashFlow': -665760.0, 'financingCashFlow': -36604429.0, 'roe': 18.910857931075384, 'roa': 4.708189704766772, 'netProfitMarginQuarter': 27.470284058066657, 'netProfitMarginAccum': 29.261927109168077, 'de': 6.610552796126678, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.08273463119866231}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TTB', 'year': '2019', 'quarter': '4', 'financialStatementType': 'C', 'dateAsof': '2019-12-31', 'accountPeriod': 'C', 'totalAssets': 1858190275.0, 'totalLiabilities': 1663378794.0, 'paidupShareCapital': 91541387.0, 'shareholderEquity': 194776870.0, 'totalEquity': 194811481.0, 'totalRevenueQuarter': 16469091.0, 'totalRevenueAccum': 52251822.0, 'totalExpensesQuarter': 15004932.0, 'totalExpensesAccum': 47228018.0, 'ebitQuarter': 6259523.0, 'ebitAccum': 21781602.0, 'netProfitQuarter': 1615140.0, 'netProfitAccum': 7222478.0, 'epsQuarter': 0.02, 'epsAccum': 0.15, 'operatingCashFlow': 19509556.0, 'investingCashFlow': -145257298.0, 'financingCashFlow': 125537096.0, 'roe': 4.920685210960398, 'roa': 1.584172050162988, 'netProfitMarginQuarter': 9.807147218993446, 'netProfitMarginAccum': 13.822457712575074, 'de': 8.538402282358296, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.038002657464079784}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'BBL', 'year': '2020', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2020-03-31', 'accountPeriod': 'C', 'totalAssets': 3395290082.0, 'totalLiabilities': 2979984954.0, 'paidupShareCapital': 19088429.0, 'shareholderEquity': 414848532.0, 'totalEquity': 415305128.0, 'totalRevenueQuarter': 38455718.0, 'totalRevenueAccum': 38455718.0, 'totalExpensesQuarter': 27999007.0, 'totalExpensesAccum': 27999007.0, 'ebitQuarter': 18735277.0, 'ebitAccum': 18735277.0, 'netProfitQuarter': 7670508.0, 'netProfitAccum': 7670508.0, 'epsQuarter': 4.02, 'epsAccum': 4.02, 'operatingCashFlow': 48127253.0, 'investingCashFlow': -23674889.0, 'financingCashFlow': -9845161.0, 'roe': 8.203337783231987, 'roa': 2.6053186016830447, 'netProfitMarginQuarter': 20.18234843515339, 'netProfitMarginAccum': 20.18234843515339, 'de': 7.175410928227209, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.04825824922515738}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KBANK', 'year': '2020', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2020-03-31', 'accountPeriod': 'C', 'totalAssets': 3483527004.0, 'totalLiabilities': 3033814358.0, 'paidupShareCapital': 23932602.0, 'shareholderEquity': 406788660.0, 'totalEquity': 449712646.0, 'totalRevenueQuarter': 47377359.0, 'totalRevenueAccum': 47377359.0, 'totalExpensesQuarter': 38535095.0, 'totalExpensesAccum': 38535095.0, 'ebitQuarter': 11797239.0, 'ebitAccum': 11797239.0, 'netProfitQuarter': 6581680.0, 'netProfitAccum': 6581680.0, 'epsQuarter': 2.75, 'epsAccum': 2.75, 'operatingCashFlow': 54161001.0, 'investingCashFlow': -34393660.0, 'financingCashFlow': -3768254.0, 'roe': 8.830493883698821, 'roa': 2.183239389457622, 'netProfitMarginQuarter': 11.13703066479497, 'netProfitMarginAccum': 11.13703066479497, 'de': 6.746117515227713, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.056454009369000364}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTB', 'year': '2020', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2020-03-31', 'accountPeriod': 'C', 'totalAssets': 3163060358.0, 'totalLiabilities': 2824450466.0, 'paidupShareCapital': 72005040.0, 'shareholderEquity': 327784285.0, 'totalEquity': 338609892.0, 'totalRevenueQuarter': 39380302.0, 'totalRevenueAccum': 39380302.0, 'totalExpensesQuarter': 31048419.0, 'totalExpensesAccum': 31048419.0, 'ebitQuarter': 16227164.0, 'ebitAccum': 16227164.0, 'netProfitQuarter': 6466532.0, 'netProfitAccum': 6466532.0, 'epsQuarter': 0.46, 'epsAccum': 0.46, 'operatingCashFlow': 7292570.0, 'investingCashFlow': -16905508.0, 'financingCashFlow': 413349.0, 'roe': 8.85330410485453, 'roa': 2.363781583346561, 'netProfitMarginQuarter': 18.516427324503503, 'netProfitMarginAccum': 18.516427324503503, 'de': 8.341311145156975, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.051249267706125}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTC', 'year': '2020', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2020-03-31', 'accountPeriod': 'C', 'totalAssets': 79623802.0, 'totalLiabilities': 58247792.0, 'paidupShareCapital': 2578334.0, 'shareholderEquity': 21348846.0, 'totalEquity': 21376010.0, 'totalRevenueQuarter': 4830262.0, 'totalRevenueAccum': 4830262.0, 'totalExpensesQuarter': 2422466.0, 'totalExpensesAccum': 2422466.0, 'ebitQuarter': 2431841.0, 'ebitAccum': 2431841.0, 'netProfitQuarter': 1641140.0, 'netProfitAccum': 1641140.0, 'epsQuarter': 0.64, 'epsAccum': 0.64, 'operatingCashFlow': 5451040.27, 'investingCashFlow': -63864.0, 'financingCashFlow': -5682186.0, 'roe': 27.18232142383715, 'roa': 11.068964064288211, 'netProfitMarginQuarter': 33.97260852516903, 'netProfitMarginAccum': 33.97260852516903, 'de': 2.7249141444076797, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.24025771326518672}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'MTC', 'year': '2020', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2020-03-31', 'accountPeriod': 'C', 'totalAssets': 68013397.0, 'totalLiabilities': 50674059.0, 'paidupShareCapital': 2120000.0, 'shareholderEquity': 17339338.0, 'totalEquity': 17339338.0, 'totalRevenueQuarter': 3540110.0, 'totalRevenueAccum': 3540110.0, 'totalExpensesQuarter': 1422822.0, 'totalExpensesAccum': 1422822.0, 'ebitQuarter': 1986319.0, 'ebitAccum': 1986319.0, 'netProfitQuarter': 1237342.0, 'netProfitAccum': 1237342.0, 'epsQuarter': 0.58, 'epsAccum': 0.58, 'operatingCashFlow': -433087.0, 'investingCashFlow': -156979.0, 'financingCashFlow': 622954.0, 'roe': 25.548584092426132, 'roa': 10.474877398051445, 'netProfitMarginQuarter': 34.95207776029559, 'netProfitMarginAccum': 34.95207776029559, 'de': 2.9224909855266676, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.1926018919478467}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TISCO', 'year': '2020', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2020-03-31', 'accountPeriod': 'C', 'totalAssets': 303554686.0, 'totalLiabilities': 262420021.0, 'paidupShareCapital': 8006555.0, 'shareholderEquity': 41131443.0, 'totalEquity': 41134665.0, 'totalRevenueQuarter': 6155549.0, 'totalRevenueAccum': 6155549.0, 'totalExpensesQuarter': 4328920.0, 'totalExpensesAccum': 4328920.0, 'ebitQuarter': 2938809.0, 'ebitAccum': 2938809.0, 'netProfitQuarter': 1486067.0, 'netProfitAccum': 1486067.0, 'epsQuarter': 1.86, 'epsAccum': 1.86, 'operatingCashFlow': 1781715.0, 'investingCashFlow': -3753237.0, 'financingCashFlow': 2147052.0, 'roe': 17.430245024892113, 'roa': 4.533613936268075, 'netProfitMarginQuarter': 24.143532932643375, 'netProfitMarginAccum': 24.143532932643375, 'de': 6.379534657690782, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.08318135658330028}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TTB', 'year': '2020', 'quarter': '1', 'financialStatementType': 'C', 'dateAsof': '2020-03-31', 'accountPeriod': 'C', 'totalAssets': 1889189445.0, 'totalLiabilities': 1690776037.0, 'paidupShareCapital': 91541387.0, 'shareholderEquity': 198378269.0, 'totalEquity': 198413408.0, 'totalRevenueQuarter': 24459738.0, 'totalRevenueAccum': 24459738.0, 'totalExpensesQuarter': 20276038.0, 'totalExpensesAccum': 20276038.0, 'ebitQuarter': 10696385.0, 'ebitAccum': 10696385.0, 'netProfitQuarter': 4163461.0, 'netProfitAccum': 4163461.0, 'epsQuarter': 0.04, 'epsAccum': 0.04, 'operatingCashFlow': 9766504.0, 'investingCashFlow': -1807235.0, 'financingCashFlow': -11041140.0, 'roe': 6.564942962482574, 'roa': 1.9935326709704875, 'netProfitMarginQuarter': 17.02477761617888, 'netProfitMarginAccum': 17.02477761617888, 'de': 8.521480750937961, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.04677059702355118}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'BBL', 'year': '2020', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2020-06-30', 'accountPeriod': 'C', 'totalAssets': 3806363317.0, 'totalLiabilities': 3367649962.0, 'paidupShareCapital': 19088429.0, 'shareholderEquity': 438339959.0, 'totalEquity': 438713355.0, 'totalRevenueQuarter': 35773267.0, 'totalRevenueAccum': 74228985.0, 'totalExpensesQuarter': 39166830.0, 'totalExpensesAccum': 67165837.0, 'ebitQuarter': 13110602.0, 'ebitAccum': 31845879.0, 'netProfitQuarter': 3094984.0, 'netProfitAccum': 10765492.0, 'epsQuarter': 1.62, 'epsAccum': 5.64, 'operatingCashFlow': 127549216.0, 'investingCashFlow': -109471796.0, 'financingCashFlow': -10369480.0, 'roe': 6.548170425229412, 'roa': 2.199716510040505, 'netProfitMarginQuarter': 8.908649579027825, 'netProfitMarginAccum': 14.749200733379286, 'de': 7.676196595382878, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.04429646273813534}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KBANK', 'year': '2020', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2020-06-30', 'accountPeriod': 'C', 'totalAssets': 3585799598.0, 'totalLiabilities': 3135107579.0, 'paidupShareCapital': 23932602.0, 'shareholderEquity': 402386328.0, 'totalEquity': 450692019.0, 'totalRevenueQuarter': 43994152.0, 'totalRevenueAccum': 91371511.0, 'totalExpensesQuarter': 43742330.0, 'totalExpensesAccum': 82277425.0, 'ebitQuarter': 12656868.0, 'ebitAccum': 24454107.0, 'netProfitQuarter': 2968546.0, 'netProfitAccum': 9550226.0, 'epsQuarter': 1.27, 'epsAccum': 4.02, 'operatingCashFlow': 121479569.0, 'investingCashFlow': -105030116.0, 'financingCashFlow': -29261180.0, 'roe': 7.091652415404136, 'roa': 1.873973573781113, 'netProfitMarginQuarter': 14.454059712299944, 'netProfitMarginAccum': 12.734135479055391, 'de': 6.956208334809674, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.05390112145276378}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTB', 'year': '2020', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2020-06-30', 'accountPeriod': 'C', 'totalAssets': 3171322531.0, 'totalLiabilities': 2823028943.0, 'paidupShareCapital': 72005040.0, 'shareholderEquity': 338035798.0, 'totalEquity': 348293588.0, 'totalRevenueQuarter': 38282044.0, 'totalRevenueAccum': 77662346.0, 'totalExpensesQuarter': 34996466.0, 'totalExpensesAccum': 66044885.0, 'ebitQuarter': 11475473.0, 'ebitAccum': 27702637.0, 'netProfitQuarter': 3755492.0, 'netProfitAccum': 10222024.0, 'epsQuarter': 0.27, 'epsAccum': 0.73, 'operatingCashFlow': -42296844.0, 'investingCashFlow': 40114555.0, 'financingCashFlow': -12187213.0, 'roe': 7.320397926006016, 'roa': 2.155245631632298, 'netProfitMarginQuarter': 11.358560164655785, 'netProfitMarginAccum': 14.988105046427519, 'de': 8.105314138025419, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.05242293958394049}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTC', 'year': '2020', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2020-06-30', 'accountPeriod': 'C', 'totalAssets': 79285015.0, 'totalLiabilities': 59029014.0, 'paidupShareCapital': 2578334.0, 'shareholderEquity': 20229074.0, 'totalEquity': 20256001.0, 'totalRevenueQuarter': 4701666.0, 'totalRevenueAccum': 9531927.0, 'totalExpensesQuarter': 2886243.0, 'totalExpensesAccum': 5308709.0, 'ebitQuarter': 1824496.0, 'ebitAccum': 4256337.0, 'netProfitQuarter': 1149155.0, 'netProfitAccum': 2790295.0, 'epsQuarter': 0.45, 'epsAccum': 1.08, 'operatingCashFlow': 7337280.0, 'investingCashFlow': -94561.0, 'financingCashFlow': -7464769.0, 'roe': 27.559504651572286, 'roa': 10.753945256868526, 'netProfitMarginQuarter': 24.43640190519701, 'netProfitMarginAccum': 29.268835147394647, 'de': 2.914149441442069, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.2409018566749341}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'MTC', 'year': '2020', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2020-06-30', 'accountPeriod': 'C', 'totalAssets': 70083158.0, 'totalLiabilities': 52111800.0, 'paidupShareCapital': 2120000.0, 'shareholderEquity': 17971358.0, 'totalEquity': 17971358.0, 'totalRevenueQuarter': 3565263.0, 'totalRevenueAccum': 7105372.0, 'totalExpensesQuarter': 1544700.0, 'totalExpensesAccum': 2857644.0, 'ebitQuarter': 2020563.0, 'ebitAccum': 4006882.0, 'netProfitQuarter': 1266553.0, 'netProfitAccum': 2503895.0, 'epsQuarter': 0.6, 'epsAccum': 1.18, 'operatingCashFlow': 680362.0, 'investingCashFlow': -352279.0, 'financingCashFlow': 852454.0, 'roe': 25.819103765002065, 'roa': 10.622625952443524, 'netProfitMarginQuarter': 35.5248126155069, 'netProfitMarginAccum': 35.239463887323566, 'de': 2.899714089497299, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.19264940843561873}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TISCO', 'year': '2020', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2020-06-30', 'accountPeriod': 'C', 'totalAssets': 275110804.0, 'totalLiabilities': 238864020.0, 'paidupShareCapital': 8006555.0, 'shareholderEquity': 36243597.0, 'totalEquity': 36246784.0, 'totalRevenueQuarter': 5412990.0, 'totalRevenueAccum': 11508653.0, 'totalExpensesQuarter': 3768332.0, 'totalExpensesAccum': 8037366.0, 'ebitQuarter': 2659397.0, 'ebitAccum': 5598204.0, 'netProfitQuarter': 1329415.0, 'netProfitAccum': 2815481.0, 'epsQuarter': 1.66, 'epsAccum': 3.52, 'operatingCashFlow': 17272486.0, 'investingCashFlow': -2764367.0, 'financingCashFlow': -14446505.0, 'roe': 18.2687246500167, 'roa': 4.504709243648577, 'netProfitMarginQuarter': 24.561323778540142, 'netProfitMarginAccum': 24.465660751088766, 'de': 6.589936916886199, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.08585806333778766}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TTB', 'year': '2020', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2020-06-30', 'accountPeriod': 'C', 'totalAssets': 1893152342.0, 'totalLiabilities': 1691925865.0, 'paidupShareCapital': 91541387.0, 'shareholderEquity': 201190621.0, 'totalEquity': 201226477.0, 'totalRevenueQuarter': 21796282.0, 'totalRevenueAccum': 46256020.0, 'totalExpensesQuarter': 18946921.0, 'totalExpensesAccum': 39222959.0, 'ebitQuarter': 8770090.0, 'ebitAccum': 19466475.0, 'netProfitQuarter': 3094937.0, 'netProfitAccum': 7258398.0, 'epsQuarter': 0.04, 'epsAccum': 0.08, 'operatingCashFlow': -19419105.0, 'investingCashFlow': 32315130.0, 'financingCashFlow': -18674375.0, 'roe': 7.283615198217801, 'roa': 2.2491362729220317, 'netProfitMarginQuarter': 14.202968194300293, 'netProfitMarginAccum': 15.695113846803075, 'de': 8.408067816045897, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.05357187707921696}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'BBL', 'year': '2020', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2020-09-30', 'accountPeriod': 'C', 'totalAssets': 3810590601.0, 'totalLiabilities': 3369925537.0, 'paidupShareCapital': 19088429.0, 'shareholderEquity': 439508544.0, 'totalEquity': 440665064.0, 'totalRevenueQuarter': 38487559.0, 'totalRevenueAccum': 112716544.0, 'totalExpensesQuarter': 36638768.0, 'totalExpensesAccum': 103804605.0, 'ebitQuarter': 13720694.0, 'ebitAccum': 45566573.0, 'netProfitQuarter': 4017496.0, 'netProfitAccum': 14782988.0, 'epsQuarter': 2.1, 'epsAccum': 7.74, 'operatingCashFlow': 171194790.0, 'investingCashFlow': -184328681.0, 'financingCashFlow': 12890096.0, 'roe': 5.23990208226956, 'roa': 1.9174488144271697, 'netProfitMarginQuarter': 10.690249282891648, 'netProfitMarginAccum': 13.363253933690515, 'de': 7.647362616883103, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.043384911715951116}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KBANK', 'year': '2020', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2020-09-30', 'accountPeriod': 'C', 'totalAssets': 3545647971.0, 'totalLiabilities': 3089066396.0, 'paidupShareCapital': 23693276.0, 'shareholderEquity': 408715948.0, 'totalEquity': 456581575.0, 'totalRevenueQuarter': 43059948.0, 'totalRevenueAccum': 134431458.0, 'totalExpensesQuarter': 34441564.0, 'totalExpensesAccum': 116718988.0, 'ebitQuarter': 13622509.0, 'ebitAccum': 38076615.0, 'netProfitQuarter': 6678511.0, 'netProfitAccum': 16228738.0, 'epsQuarter': 2.82, 'epsAccum': 6.83, 'operatingCashFlow': 119319060.0, 'investingCashFlow': -107445743.0, 'financingCashFlow': -29591991.0, 'roe': 6.182290288082918, 'roa': 1.6740449610611807, 'netProfitMarginQuarter': 17.286790499607662, 'netProfitMarginAccum': 14.192404280849205, 'de': 6.765639625295874, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.053069264606088684}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTB', 'year': '2020', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2020-09-30', 'accountPeriod': 'C', 'totalAssets': 3104475291.0, 'totalLiabilities': 2754725649.0, 'paidupShareCapital': 72005040.0, 'shareholderEquity': 338872667.0, 'totalEquity': 349749642.0, 'totalRevenueQuarter': 35367452.0, 'totalRevenueAccum': 113029797.0, 'totalExpensesQuarter': 33333100.0, 'totalExpensesAccum': 99377984.0, 'ebitQuarter': 9768727.0, 'ebitAccum': 37471364.0, 'netProfitQuarter': 3057136.0, 'netProfitAccum': 13279160.0, 'epsQuarter': 0.22, 'epsAccum': 0.95, 'operatingCashFlow': -16340748.0, 'investingCashFlow': 24309343.0, 'financingCashFlow': -22048385.0, 'roe': 6.148103069954356, 'roa': 1.8762510844370666, 'netProfitMarginQuarter': 10.394644771130247, 'netProfitMarginAccum': 13.550794044158108, 'de': 7.876278681080108, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.05031930399319092}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTC', 'year': '2020', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2020-09-30', 'accountPeriod': 'C', 'totalAssets': 83687183.0, 'totalLiabilities': 62210396.0, 'paidupShareCapital': 2578334.0, 'shareholderEquity': 21450150.0, 'totalEquity': 21476787.0, 'totalRevenueQuarter': 4637474.0, 'totalRevenueAccum': 14169401.0, 'totalExpensesQuarter': 2725685.0, 'totalExpensesAccum': 8034393.0, 'ebitQuarter': 1916483.0, 'ebitAccum': 6172820.0, 'netProfitQuarter': 1221076.0, 'netProfitAccum': 4011371.0, 'epsQuarter': 0.47, 'epsAccum': 1.56, 'operatingCashFlow': 5973329.0, 'investingCashFlow': -104549.0, 'financingCashFlow': -4012431.0, 'roe': 25.19208397144076, 'roa': 9.927189280585536, 'netProfitMarginQuarter': 26.324374001881196, 'netProfitMarginAccum': 28.305148538036295, 'de': 2.8966342125570272, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.22647901961283606}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'MTC', 'year': '2020', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2020-09-30', 'accountPeriod': 'C', 'totalAssets': 72901645.0, 'totalLiabilities': 53588050.0, 'paidupShareCapital': 2120000.0, 'shareholderEquity': 19313595.0, 'totalEquity': 19313595.0, 'totalRevenueQuarter': 3736650.0, 'totalRevenueAccum': 10842022.0, 'totalExpensesQuarter': 1585239.0, 'totalExpensesAccum': 4337324.0, 'ebitQuarter': 2151411.0, 'ebitAccum': 6158293.0, 'netProfitQuarter': 1339973.0, 'netProfitAccum': 3843868.0, 'epsQuarter': 0.63, 'epsAccum': 1.81, 'operatingCashFlow': -1198056.0, 'investingCashFlow': -523729.0, 'financingCashFlow': 1732755.0, 'roe': 25.432563331684236, 'roa': 10.805226493860324, 'netProfitMarginQuarter': 35.860275915592844, 'netProfitMarginAccum': 35.45342372483657, 'de': 2.7746284417789644, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.19258928190166355}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TISCO', 'year': '2020', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2020-09-30', 'accountPeriod': 'C', 'totalAssets': 275949118.0, 'totalLiabilities': 238104141.0, 'paidupShareCapital': 8006555.0, 'shareholderEquity': 37841683.0, 'totalEquity': 37844977.0, 'totalRevenueQuarter': 5587953.0, 'totalRevenueAccum': 17069219.0, 'totalExpensesQuarter': 3580703.0, 'totalExpensesAccum': 11590683.0, 'ebitQuarter': 2838787.0, 'ebitAccum': 8436991.0, 'netProfitQuarter': 1611530.0, 'netProfitAccum': 4427011.0, 'epsQuarter': 2.01, 'epsAccum': 5.53, 'operatingCashFlow': 20960044.0, 'investingCashFlow': -4510483.0, 'financingCashFlow': -16511224.0, 'roe': 16.72622384352591, 'roa': 4.293945859637371, 'netProfitMarginQuarter': 28.841276939874046, 'netProfitMarginAccum': 25.937361281731754, 'de': 6.291565218813583, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.0852346440397439}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TTB', 'year': '2020', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2020-09-30', 'accountPeriod': 'C', 'totalAssets': 1840852801.0, 'totalLiabilities': 1637925192.0, 'paidupShareCapital': 91588946.0, 'shareholderEquity': 202891276.0, 'totalEquity': 202927609.0, 'totalRevenueQuarter': 21609740.0, 'totalRevenueAccum': 67865760.0, 'totalExpensesQuarter': 19695672.0, 'totalExpensesAccum': 58918631.0, 'ebitQuarter': 6167742.0, 'ebitAccum': 25634218.0, 'netProfitQuarter': 1618900.0, 'netProfitAccum': 8877299.0, 'epsQuarter': 0.02, 'epsAccum': 0.09, 'operatingCashFlow': 11558347.0, 'investingCashFlow': 2703420.0, 'financingCashFlow': -19193343.0, 'roe': 6.869397531413224, 'roa': 2.326521125705718, 'netProfitMarginQuarter': 7.493583911699076, 'netProfitMarginAccum': 13.083593258220345, 'de': 8.071475340745772, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.061518908203570095}
# ...
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TISCO', 'year': '2023', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2023-06-30', 'accountPeriod': 'C', 'totalAssets': 274358889.0, 'totalLiabilities': 234146022.0, 'paidupShareCapital': 8006555.0, 'shareholderEquity': 40209677.0, 'totalEquity': 40212867.0, 'totalRevenueQuarter': 5752233.0, 'totalRevenueAccum': 11352345.0, 'totalExpensesQuarter': 3526838.0, 'totalExpensesAccum': 6923335.0, 'ebitQuarter': 3280472.0, 'ebitAccum': 6361392.0, 'netProfitQuarter': 1853888.0, 'netProfitAccum': 3646468.0, 'epsQuarter': 2.32, 'epsAccum': 4.55, 'operatingCashFlow': 5824876.0, 'investingCashFlow': 499924.0, 'financingCashFlow': -6382273.0, 'roe': 18.190033722663657, 'roa': 4.617447022591007, 'netProfitMarginQuarter': 32.23127435901849, 'netProfitMarginAccum': 32.123010708360255, 'de': 5.822664223369102, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.08507478836800841}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TLI', 'year': '2023', 'quarter': '2', 'financialStatementType': 'E', 'dateAsof': '2023-06-30', 'accountPeriod': 'C', 'totalAssets': 561072700.0, 'totalLiabilities': 460467074.0, 'paidupShareCapital': 11450000.0, 'shareholderEquity': 100605626.0, 'totalEquity': 100605626.0, 'totalRevenueQuarter': 24959170.0, 'totalRevenueAccum': 49001443.0, 'totalExpensesQuarter': 21901215.0, 'totalExpensesAccum': 42055486.0, 'ebitQuarter': 3057955.0, 'ebitAccum': 6945957.0, 'netProfitQuarter': 2511583.0, 'netProfitAccum': 5640448.0, 'epsQuarter': 0.22, 'epsAccum': 0.49, 'operatingCashFlow': 2968981.0, 'investingCashFlow': -219677.0, 'financingCashFlow': -3434929.0, 'roe': 10.277344910720329, 'roa': 2.0412485249983696, 'netProfitMarginQuarter': 10.062766510264565, 'netProfitMarginAccum': 11.510779386639696, 'de': 4.5769515315177305, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.19061102693062254}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TTB', 'year': '2023', 'quarter': '2', 'financialStatementType': 'C', 'dateAsof': '2023-06-30', 'accountPeriod': 'C', 'totalAssets': 1822215492.0, 'totalLiabilities': 1598316348.0, 'paidupShareCapital': 91938773.0, 'shareholderEquity': 223897996.0, 'totalEquity': 223899144.0, 'totalRevenueQuarter': 23472008.0, 'totalRevenueAccum': 45718311.0, 'totalExpensesQuarter': 18341956.0, 'totalExpensesAccum': 35835652.0, 'ebitQuarter': 11001999.0, 'ebitAccum': 21266180.0, 'netProfitQuarter': 4566286.0, 'netProfitAccum': 8860801.0, 'epsQuarter': 0.05, 'epsAccum': 0.09, 'operatingCashFlow': -13965450.0, 'investingCashFlow': 17720399.0, 'financingCashFlow': -5215127.0, 'roe': 7.52026094270272, 'roa': 2.077814769815044, 'netProfitMarginQuarter': 19.454206900406646, 'netProfitMarginAccum': 19.38131966423694, 'de': 7.138554973662606, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.04836908617368639}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'BBL', 'year': '2023', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2023-09-30', 'accountPeriod': 'C', 'totalAssets': 4559184766.0, 'totalLiabilities': 4029233549.0, 'paidupShareCapital': 19088429.0, 'shareholderEquity': 528117233.0, 'totalEquity': 529951217.0, 'totalRevenueQuarter': 61734517.0, 'totalRevenueAccum': 177210871.0, 'totalExpensesQuarter': 48094146.0, 'totalExpensesAccum': 142004370.0, 'ebitQuarter': 30550093.0, 'ebitAccum': 86849756.0, 'netProfitQuarter': 11349908.0, 'netProfitAccum': 32772714.0, 'epsQuarter': 5.95, 'epsAccum': 17.17, 'operatingCashFlow': 79594534.0, 'investingCashFlow': -126689782.0, 'financingCashFlow': 34635505.0, 'roe': 7.771645337709087, 'roa': 2.394231403534857, 'netProfitMarginQuarter': 18.560692715875625, 'netProfitMarginAccum': 18.68148427530724, 'de': 7.6030272593939525, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.05144538332019237}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KBANK', 'year': '2023', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2023-09-30', 'accountPeriod': 'C', 'totalAssets': 4266003888.0, 'totalLiabilities': 3676666208.0, 'paidupShareCapital': 23693276.0, 'shareholderEquity': 525160492.0, 'totalEquity': 589337680.0, 'totalRevenueQuarter': 76844306.0, 'totalRevenueAccum': 225828758.0, 'totalExpensesQuarter': 63475318.0, 'totalExpensesAccum': 190580586.0, 'ebitQuarter': 23718117.0, 'ebitAccum': 68326410.0, 'netProfitQuarter': 11281857.0, 'netProfitAccum': 33017191.0, 'epsQuarter': 4.6, 'epsAccum': 13.62, 'operatingCashFlow': 3306172.0, 'investingCashFlow': -13488028.0, 'financingCashFlow': -5273735.0, 'roe': 7.062162612179451, 'roa': 1.8638295601791526, 'netProfitMarginQuarter': 15.177192178689205, 'netProfitMarginAccum': 15.440380272560326, 'de': 6.238640991018935, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.07032341109359928}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTB', 'year': '2023', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2023-09-30', 'accountPeriod': 'C', 'totalAssets': 3627348717.0, 'totalLiabilities': 3218603259.0, 'paidupShareCapital': 72005040.0, 'shareholderEquity': 391207683.0, 'totalEquity': 408745458.0, 'totalRevenueQuarter': 49331844.0, 'totalRevenueAccum': 137985898.0, 'totalExpensesQuarter': 36810963.0, 'totalExpensesAccum': 101862443.0, 'ebitQuarter': 23980971.0, 'ebitAccum': 69018686.0, 'netProfitQuarter': 10282170.0, 'netProfitAccum': 30504962.0, 'epsQuarter': 0.74, 'epsAccum': 2.18, 'operatingCashFlow': -9103868.0, 'investingCashFlow': 1655571.0, 'financingCashFlow': -3961519.0, 'roe': 10.253987895230223, 'roa': 2.3796648344300744, 'netProfitMarginQuarter': 22.75119292114846, 'netProfitMarginAccum': 24.117561636624636, 'de': 7.874346236772128, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.049045062071867186}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTC', 'year': '2023', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2023-09-30', 'accountPeriod': 'C', 'totalAssets': 104577925.0, 'totalLiabilities': 70462174.0, 'paidupShareCapital': 2578334.0, 'shareholderEquity': 33922378.0, 'totalEquity': 34115751.0, 'totalRevenueQuarter': 6436965.0, 'totalRevenueAccum': 18676884.0, 'totalExpensesQuarter': 3728956.0, 'totalExpensesAccum': 10653308.0, 'ebitQuarter': 2743988.0, 'ebitAccum': 8131223.0, 'netProfitQuarter': 1856522.0, 'netProfitAccum': 5534065.0, 'epsQuarter': 0.72, 'epsAccum': 2.15, 'operatingCashFlow': 2959524.0, 'investingCashFlow': -235892.0, 'financingCashFlow': -2161364.0, 'roe': 22.64335743069267, 'roa': 10.688260703912032, 'netProfitMarginQuarter': 28.559328814122804, 'netProfitMarginAccum': 29.474408043654392, 'de': 2.0653853992544384, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.2505177633497033}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'MTC', 'year': '2023', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2023-09-30', 'accountPeriod': 'C', 'totalAssets': 145506023.0, 'totalLiabilities': 114863881.0, 'paidupShareCapital': 2120000.0, 'shareholderEquity': 30642142.0, 'totalEquity': 30642142.0, 'totalRevenueQuarter': 6299479.0, 'totalRevenueAccum': 17970699.0, 'totalExpensesQuarter': 3356320.0, 'totalExpensesAccum': 10141959.0, 'ebitQuarter': 2609026.0, 'ebitAccum': 7199934.0, 'netProfitQuarter': 1285138.0, 'netProfitAccum': 3555314.0, 'epsQuarter': 0.61, 'epsAccum': 1.68, 'operatingCashFlow': -10247266.0, 'investingCashFlow': -370592.0, 'financingCashFlow': 10206264.0, 'roe': 15.981156556253591, 'roa': 6.984741122962645, 'netProfitMarginQuarter': 20.40070297877015, 'netProfitMarginAccum': 19.783949416770042, 'de': 3.7485591248810217, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.17550581446953267}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'SCB', 'year': '2023', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2023-09-30', 'accountPeriod': 'C', 'totalAssets': 3539048944.0, 'totalLiabilities': 3067155229.0, 'paidupShareCapital': 33671073.0, 'shareholderEquity': 466394411.0, 'totalEquity': 471893715.0, 'totalRevenueQuarter': 53429632.0, 'totalRevenueAccum': 155374379.0, 'totalExpensesQuarter': 43230306.0, 'totalExpensesAccum': 122101737.0, 'ebitQuarter': 22146774.0, 'ebitAccum': 68442651.0, 'netProfitQuarter': 9663100.0, 'netProfitAccum': 32526603.0, 'epsQuarter': 2.87, 'epsAccum': 9.66, 'operatingCashFlow': -28679440.0, 'investingCashFlow': 9237553.0, 'financingCashFlow': 8672527.0, 'roe': 8.590823917899455, 'roa': 2.4163192500280424, 'netProfitMarginQuarter': 18.189082792110565, 'netProfitMarginAccum': 21.046126916458988, 'de': 6.49967382803562, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.058060940931601177}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TIDLOR', 'year': '2023', 'quarter': '3', 'financialStatementType': 'E', 'dateAsof': '2023-09-30', 'accountPeriod': 'C', 'totalAssets': 94522079.0, 'totalLiabilities': 66957064.0, 'paidupShareCapital': 10395077.0, 'shareholderEquity': 27565015.0, 'totalEquity': 27565015.0, 'totalRevenueQuarter': 4834320.0, 'totalRevenueAccum': 13709383.0, 'totalExpensesQuarter': 3090420.0, 'totalExpensesAccum': 8784540.0, 'ebitQuarter': 1743900.0, 'ebitAccum': 4924843.0, 'netProfitQuarter': 1006839.0, 'netProfitAccum': 2889190.0, 'epsQuarter': 0.36, 'epsAccum': 1.08, 'operatingCashFlow': -6843522.0, 'investingCashFlow': -541802.0, 'financingCashFlow': 6547683.0, 'roe': 14.210697019260618, 'roa': 7.265027509640438, 'netProfitMarginQuarter': 20.826900163828626, 'netProfitMarginAccum': 21.074544346744123, 'de': 2.4290595887577062, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.20821198299737764}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TISCO', 'year': '2023', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2023-09-30', 'accountPeriod': 'C', 'totalAssets': 273932581.0, 'totalLiabilities': 233453253.0, 'paidupShareCapital': 8006555.0, 'shareholderEquity': 40476013.0, 'totalEquity': 40479328.0, 'totalRevenueQuarter': 6055467.0, 'totalRevenueAccum': 17407812.0, 'totalExpensesQuarter': 3692108.0, 'totalExpensesAccum': 10615444.0, 'ebitQuarter': 3441326.0, 'ebitAccum': 9802717.0, 'netProfitQuarter': 1874485.0, 'netProfitAccum': 5520953.0, 'epsQuarter': 2.34, 'epsAccum': 6.9, 'operatingCashFlow': 8907856.0, 'investingCashFlow': -1049366.0, 'financingCashFlow': -8065916.0, 'roe': 17.982469987414056, 'roa': 4.788380152574751, 'netProfitMarginQuarter': 30.95731510055294, 'netProfitMarginAccum': 31.71751280402155, 'de': 5.767221555654284, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.08654082410773487}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TLI', 'year': '2023', 'quarter': '3', 'financialStatementType': 'E', 'dateAsof': '2023-09-30', 'accountPeriod': 'C', 'totalAssets': 564752702.0, 'totalLiabilities': 465820493.0, 'paidupShareCapital': 11450000.0, 'shareholderEquity': 98932209.0, 'totalEquity': 98932209.0, 'totalRevenueQuarter': 29317892.0, 'totalRevenueAccum': 78319335.0, 'totalExpensesQuarter': 26705756.0, 'totalExpensesAccum': 68761242.0, 'ebitQuarter': 2612136.0, 'ebitAccum': 9558093.0, 'netProfitQuarter': 2088201.0, 'netProfitAccum': 7728649.0, 'epsQuarter': 0.18, 'epsAccum': 0.67, 'operatingCashFlow': -467238.0, 'investingCashFlow': -302155.0, 'financingCashFlow': -3434929.0, 'roe': 9.518801108112163, 'roa': 1.9908675358764747, 'netProfitMarginQuarter': 7.122616455507783, 'netProfitMarginAccum': 9.868123880265326, 'de': 4.708481673546782, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.19337230248693818}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TTB', 'year': '2023', 'quarter': '3', 'financialStatementType': 'C', 'dateAsof': '2023-09-30', 'accountPeriod': 'C', 'totalAssets': 1772044332.0, 'totalLiabilities': 1548403187.0, 'paidupShareCapital': 92022289.0, 'shareholderEquity': 223640000.0, 'totalEquity': 223641145.0, 'totalRevenueQuarter': 23989824.0, 'totalRevenueAccum': 69708135.0, 'totalExpensesQuarter': 18594114.0, 'totalExpensesAccum': 54429766.0, 'ebitQuarter': 11420816.0, 'ebitAccum': 32686996.0, 'netProfitQuarter': 4734890.0, 'netProfitAccum': 13595691.0, 'epsQuarter': 0.05, 'epsAccum': 0.14, 'operatingCashFlow': -21792218.0, 'investingCashFlow': 27434072.0, 'financingCashFlow': -7575663.0, 'roe': 7.95879327942881, 'roa': 2.291081533768394, 'netProfitMarginQuarter': 19.73710186452389, 'netProfitMarginAccum': 19.50376093120265, 'de': 6.923606060950904, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.05105707690333147}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'KTC', 'year': '2023', 'quarter': '4', 'financialStatementType': 'C', 'dateAsof': '2023-12-31', 'accountPeriod': 'C', 'totalAssets': 112813683.55, 'totalLiabilities': 76968201.14, 'paidupShareCapital': 2578334.07, 'shareholderEquity': 35681572.43, 'totalEquity': 35845482.4, 'totalRevenueQuarter': 6604996.51, 'totalRevenueAccum': 25281880.51, 'totalExpensesQuarter': 4041399.08, 'totalExpensesAccum': 14694707.08, 'ebitQuarter': 2639554.8, 'ebitAccum': 10770777.8, 'netProfitQuarter': 1761329.62, 'netProfitAccum': 7295394.62, 'epsQuarter': 0.68, 'epsAccum': 2.83, 'operatingCashFlow': 2102975.33, 'investingCashFlow': -348918.52, 'financingCashFlow': 1407749.29, 'roe': 21.765995506665078, 'roa': 10.03755104343286, 'netProfitMarginQuarter': 26.415305554794305, 'netProfitMarginAccum': 28.67520478602246, 'de': 2.147221797188033, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.23560802274938342}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'SCB', 'year': '2023', 'quarter': '4', 'financialStatementType': 'C', 'dateAsof': '2023-12-31', 'accountPeriod': 'C', 'totalAssets': 3438721930.0, 'totalLiabilities': 2954988615.0, 'paidupShareCapital': 33671073.0, 'shareholderEquity': 478082219.0, 'totalEquity': 483733315.0, 'totalRevenueQuarter': 55182415.0, 'totalRevenueAccum': 210556794.0, 'totalExpensesQuarter': 42045575.0, 'totalExpensesAccum': 164147312.0, 'ebitQuarter': 23719122.0, 'ebitAccum': 92161773.0, 'netProfitQuarter': 10994731.0, 'netProfitAccum': 43521334.0, 'epsQuarter': 3.27, 'epsAccum': 12.93, 'operatingCashFlow': -10040781.0, 'investingCashFlow': -4794273.0, 'financingCashFlow': 8371557.0, 'roe': 9.266622301233275, 'roa': 2.674000958925706, 'netProfitMarginQuarter': 20.057335294223712, 'netProfitMarginAccum': 20.786985861876296, 'de': 6.108714292295539, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.06109138862425339}
# Missing or None value for fixedAssetTurnover in item: {'symbol': 'TTB', 'year': '2023', 'quarter': '4', 'financialStatementType': 'C', 'dateAsof': '2023-12-31', 'accountPeriod': 'C', 'totalAssets': 1824433718.0, 'totalLiabilities': 1595086585.0, 'paidupShareCapital': 92246413.0, 'shareholderEquity': 229347090.0, 'totalEquity': 229347133.0, 'totalRevenueQuarter': 24822366.0, 'totalRevenueAccum': 94530501.0, 'totalExpensesQuarter': 24620438.0, 'totalExpensesAccum': 79050204.0, 'ebitQuarter': 6721616.0, 'ebitAccum': 39408612.0, 'netProfitQuarter': 4866490.0, 'netProfitAccum': 18462181.0, 'epsQuarter': 0.05, 'epsAccum': 0.19, 'operatingCashFlow': -20449064.0, 'investingCashFlow': 32770642.0, 'financingCashFlow': -12339903.0, 'roe': 8.235546195511265, 'roa': 2.1589545046503322, 'netProfitMarginQuarter': 19.60530273383287, 'netProfitMarginAccum': 19.53042436535907, 'de': 6.954900914327104, 'fixedAssetTurnover': None, 'totalAssetTurnover': 0.05178742427183245}
